# %% [markdown]
# # imports

# %%
import os
import sys

sys.path.append(os.path.abspath("../src"))

# %%
import numpy as np
import xgboost as xgb
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
from src import *

# %% [markdown]
# # set flags

# %%
db = database_loader.DatabaseLoader(get_config('connection_string'))
DEBUG = False
SCHEMA = 'controls'

file_name = "ml_stats_dataset"
data_directory = get_config('data_directory')

input_path = os.path.join(data_directory,  f"{file_name}.parquet")
assert  os.path.exists(input_path)

# %% [markdown]
# # load the NFL stats dataset

# %%
stats_df = pd.read_parquet(input_path)
stats_df.head()
# Out:
#        season  week  spread  rush_attempts  rush_touchdowns  pass_touchdowns  \
# index
# 0        2022     1     -23              0                1                2
# 1        2022     3      -8              3                0                0
# 2        2022     4      10              5                0                2
# 3        2022     6     -10              5                0                0
# 4        2022     7       8              2                1                1
#
#        interceptions  fumble  own_kickoff_recovery  safety  ...  \
# index                                                       ...
# 0                  0       6                     0       0  ...
# 1                  0       2                     0       0  ...
# 2                  1       3                     0       0  ...
# 3                  1       4                     0       0  ...
# 4                  0       2                     0       0  ...
#
#        passing_air_yards  passing_yards_after_catch  avg_dakota  carries  \
# index
# 0                  267.0                      115.0    0.007858     22.0
# 1                  356.0                      166.0   -0.000555     21.0
# 2                  180.0                       87.0    0.011065     37.0
# 3                  333.0                      114.0    0.003919     28.0
# 4                  216.0                       94.0    0.013561     29.0
#
#        rushing_yards  receptions  targets  receiving_yards  \
# index
# 0              103.0        24.0     36.0            205.0
# 1               70.0        37.0     55.0            314.0
# 2              132.0        23.0     31.0            207.0
# 3              144.0        23.0     36.0            222.0
# 4              137.0        20.0     29.0            204.0
#
#        receiving_air_yards  receiving_yards_after_catch
# index
# 0                    266.0                        115.0
# 1                    332.0                        166.0
# 2                    182.0                         87.0
# 3                    340.0                        114.0
# 4                    216.0                         94.0
#
# [5 rows x 63 columns]

# %% [markdown]
# # perform feature selection

# %% [markdown]
# ## prepare our data for feature selection
# We'll have an X, and y set plus the original stats_df datasets, which we'll use going forward

# %%
stats_df['win'] = np.where(stats_df['spread'] > 0, 1, 0)
stats_df.drop(columns=['spread'], inplace=True)

# %%
dtype_mapping = {col: 'float' for col in stats_df.select_dtypes(include='int64')}
stats_df = stats_df.astype(dtype_mapping)

# %%
assert 0 == stats_df.isnull().sum().sum()

# %% [markdown]
# ## define helper functions

# %%
from typing import Set, Any


def correlate_to_target(df: pd.DataFrame, target_column: str, top_n: int) -> (pd.DataFrame, Set):

    # Calculate correlation matrix
    correlation_matrix = df.corr()

    # Filter and sort correlation coefficients by absolute value
    corr_df = pd.DataFrame(correlation_matrix.abs().unstack().sort_values(ascending=False))
    corr_df.reset_index(inplace=True)
    corr_df.columns = ['x', 'y', 'corr']

    not_self_correlated = (corr_df.y != target_column)
    win_correlated = (corr_df.x == target_column)

    df = corr_df.loc[ win_correlated & not_self_correlated ]\
        .sort_values(by='corr', ascending=False)\
        .drop(columns=['x'])\
        .head(top_n)\
        .copy()

    s = set(df['y'].values)

    return df, s


def calc_feature_importance(X: pd.DataFrame, y: pd.Series, top_n=30) -> (pd.DataFrame, Set):
    # Create an XGBoost model
    model = xgb.XGBRegressor()

    # Fit the model
    model.fit(X, y)

    # Get feature importance scores
    importance_scores = model.feature_importances_

    # Sort feature importance scores
    sorted_indices = importance_scores.argsort()[::-1]
    sorted_scores = importance_scores[sorted_indices]
    feature_names = X.columns[sorted_indices]

    # Get the top 'n' feature importance scores and names
    top_scores = sorted_scores[:top_n]
    top_features = feature_names[:top_n]
    df = pd.DataFrame({'y': top_features, 'corr': top_scores})

    set_xg_cols = set(top_features)
    return df, set(top_features)


def plot_correlations(scores: Any, features: Any, title: str):

    # Plot feature importance
    plt.figure(figsize=(10, 10))
    plt.barh(range(len(scores)), scores, align='center')
    plt.yticks(range(len(features)), features)
    plt.xlabel('Score')
    plt.ylabel('Column')
    plt.title(title)
    plt.show()

# %% [markdown]
# ## get cross correlations

# %%
top_correlations, set_correlations = correlate_to_target(stats_df, 'win', 30)

# %% [markdown]
# ## create xy dataset slices

# %%
import numpy as np


X = stats_df.drop(columns=['win']).copy()
y = stats_df['win']

print(X.shape)
print(y.shape)
y.value_counts()
# Out:
# (3569, 62)
# (3569,)
# 1.0    2064
# 0.0    1505
# Name: win, dtype: int64

# %% [markdown]
# ## determine feature importance

# %%
top_features, set_features = calc_feature_importance(X, y, top_n=30)

# %% [markdown]
# ## review correlations, importance and choose the best features

# %%
plot_correlations(top_features['corr'], top_features['y'], "Feature Importance")
plot_correlations(top_correlations['corr'], top_correlations['y'], 'Feature Correlations')

# %%
target_columns = list(set_features.union(set_correlations))
X = X[target_columns]

# %% [markdown]
# # validate feature set against nn model

# %% [markdown]
# ## scale and normalize data

# %%
from sklearn.preprocessing import MinMaxScaler

# Create the scaler object
scaler = MinMaxScaler()

# Normalize selected columns in a DataFrame
X = scaler.fit_transform(X)

# %% [markdown]
# ## train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %% [markdown]
# ## create and fit nn model

# %%
from keras.src.callbacks import EarlyStopping
from keras.src.optimizers import Adam
from keras import regularizers

learning_rate = .001

# Create a neural network model
model = Sequential()
model.add(Dense(32, input_dim=X.shape[1], activation='relu', kernel_regularizer=regularizers.l1(0.01)))
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l1(0.01)))
model.add(Dense(1, activation='sigmoid'))  # Single output neuron for binary classification

model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


# Train the model
r = model.fit(X_train, y_train, epochs=200, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 2023-07-08 18:04:26.573873: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2023-07-08 18:04:26.573897: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2023-07-08 18:04:26.573900: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2023-07-08 18:04:26.573929: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-08 18:04:26.573943: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
#  1/48 [..............................] - ETA: 15s - loss: 4.1004 - accuracy: 0.7188
# 2023-07-08 18:04:26.837925: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - 1s 11ms/step - loss: 3.6727 - accuracy: 0.6047 - val_loss: 3.1819 - val_accuracy: 0.6082
# Epoch 2/200
#  9/48 [====>.........................] - ETA: 0s - loss: 3.1148 - accuracy: 0.5851
# 2023-07-08 18:04:27.423704: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - 0s 7ms/step - loss: 2.7786 - accuracy: 0.6403 - val_loss: 2.3755 - val_accuracy: 0.6493
# Epoch 3/200
# 48/48 [==============================] - 0s 7ms/step - loss: 2.0437 - accuracy: 0.6815 - val_loss: 1.7249 - val_accuracy: 0.6791
# Epoch 4/200
# 48/48 [==============================] - 0s 7ms/step - loss: 1.4689 - accuracy: 0.7247 - val_loss: 1.2330 - val_accuracy: 0.7052
# Epoch 5/200
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0504 - accuracy: 0.7468 - val_loss: 0.8974 - val_accuracy: 0.7239
# Epoch 6/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7941 - accuracy: 0.7695 - val_loss: 0.7297 - val_accuracy: 0.7276
# Epoch 7/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6833 - accuracy: 0.7864 - val_loss: 0.6712 - val_accuracy: 0.7444
# Epoch 8/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6390 - accuracy: 0.7953 - val_loss: 0.6415 - val_accuracy: 0.7519
# Epoch 9/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6111 - accuracy: 0.7979 - val_loss: 0.6235 - val_accuracy: 0.7556
# Epoch 10/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5942 - accuracy: 0.8038 - val_loss: 0.6103 - val_accuracy: 0.7668
# Epoch 11/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5799 - accuracy: 0.8065 - val_loss: 0.6000 - val_accuracy: 0.7668
# Epoch 12/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5701 - accuracy: 0.8114 - val_loss: 0.5925 - val_accuracy: 0.7705
# Epoch 13/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5625 - accuracy: 0.8121 - val_loss: 0.5887 - val_accuracy: 0.7799
# Epoch 14/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5573 - accuracy: 0.8167 - val_loss: 0.5838 - val_accuracy: 0.7761
# Epoch 15/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5504 - accuracy: 0.8180 - val_loss: 0.5762 - val_accuracy: 0.7687
# Epoch 16/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5447 - accuracy: 0.8150 - val_loss: 0.5720 - val_accuracy: 0.7743
# Epoch 17/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5385 - accuracy: 0.8216 - val_loss: 0.5667 - val_accuracy: 0.7761
# Epoch 18/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5332 - accuracy: 0.8210 - val_loss: 0.5623 - val_accuracy: 0.7780
# Epoch 19/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5287 - accuracy: 0.8220 - val_loss: 0.5589 - val_accuracy: 0.7799
# Epoch 20/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5245 - accuracy: 0.8236 - val_loss: 0.5551 - val_accuracy: 0.7836
# Epoch 21/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5211 - accuracy: 0.8239 - val_loss: 0.5523 - val_accuracy: 0.7817
# Epoch 22/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5176 - accuracy: 0.8266 - val_loss: 0.5508 - val_accuracy: 0.7854
# Epoch 23/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5155 - accuracy: 0.8233 - val_loss: 0.5465 - val_accuracy: 0.7873
# Epoch 24/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5119 - accuracy: 0.8295 - val_loss: 0.5444 - val_accuracy: 0.7892
# Epoch 25/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5089 - accuracy: 0.8299 - val_loss: 0.5427 - val_accuracy: 0.7836
# Epoch 26/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5072 - accuracy: 0.8266 - val_loss: 0.5400 - val_accuracy: 0.7929
# Epoch 27/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5038 - accuracy: 0.8302 - val_loss: 0.5371 - val_accuracy: 0.7948
# Epoch 28/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5011 - accuracy: 0.8309 - val_loss: 0.5351 - val_accuracy: 0.7929
# Epoch 29/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4994 - accuracy: 0.8262 - val_loss: 0.5336 - val_accuracy: 0.7966
# Epoch 30/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4980 - accuracy: 0.8312 - val_loss: 0.5383 - val_accuracy: 0.7817
# Epoch 31/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4965 - accuracy: 0.8318 - val_loss: 0.5290 - val_accuracy: 0.8004
# Epoch 32/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4928 - accuracy: 0.8318 - val_loss: 0.5270 - val_accuracy: 0.7985
# Epoch 33/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4902 - accuracy: 0.8325 - val_loss: 0.5253 - val_accuracy: 0.7929
# Epoch 34/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4891 - accuracy: 0.8318 - val_loss: 0.5307 - val_accuracy: 0.7817
# Epoch 35/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4856 - accuracy: 0.8358 - val_loss: 0.5216 - val_accuracy: 0.8041
# Epoch 36/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4844 - accuracy: 0.8338 - val_loss: 0.5214 - val_accuracy: 0.7892
# Epoch 37/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4819 - accuracy: 0.8365 - val_loss: 0.5197 - val_accuracy: 0.7910
# Epoch 38/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4811 - accuracy: 0.8351 - val_loss: 0.5164 - val_accuracy: 0.8022
# Epoch 39/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4797 - accuracy: 0.8302 - val_loss: 0.5149 - val_accuracy: 0.8022
# Epoch 40/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4777 - accuracy: 0.8355 - val_loss: 0.5135 - val_accuracy: 0.8041
# Epoch 41/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4764 - accuracy: 0.8355 - val_loss: 0.5123 - val_accuracy: 0.8041
# Epoch 42/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4756 - accuracy: 0.8361 - val_loss: 0.5107 - val_accuracy: 0.8060
# Epoch 43/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4731 - accuracy: 0.8375 - val_loss: 0.5111 - val_accuracy: 0.8060
# Epoch 44/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4739 - accuracy: 0.8361 - val_loss: 0.5118 - val_accuracy: 0.7948
# Epoch 45/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4714 - accuracy: 0.8381 - val_loss: 0.5072 - val_accuracy: 0.8060
# Epoch 46/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4706 - accuracy: 0.8351 - val_loss: 0.5067 - val_accuracy: 0.8116
# Epoch 47/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4692 - accuracy: 0.8342 - val_loss: 0.5088 - val_accuracy: 0.7929
# Epoch 48/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4686 - accuracy: 0.8342 - val_loss: 0.5062 - val_accuracy: 0.8022
# Epoch 49/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4686 - accuracy: 0.8342 - val_loss: 0.5076 - val_accuracy: 0.7966
# Epoch 50/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4673 - accuracy: 0.8384 - val_loss: 0.5034 - val_accuracy: 0.8097
# Epoch 51/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4669 - accuracy: 0.8368 - val_loss: 0.5067 - val_accuracy: 0.8060
# Epoch 52/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4663 - accuracy: 0.8368 - val_loss: 0.5025 - val_accuracy: 0.8134
# Epoch 53/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4646 - accuracy: 0.8384 - val_loss: 0.5024 - val_accuracy: 0.8116
# Epoch 54/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4671 - accuracy: 0.8338 - val_loss: 0.5026 - val_accuracy: 0.8097
# Epoch 55/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4653 - accuracy: 0.8378 - val_loss: 0.5028 - val_accuracy: 0.8116
# Epoch 56/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4633 - accuracy: 0.8375 - val_loss: 0.5009 - val_accuracy: 0.8134
# Epoch 57/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4631 - accuracy: 0.8388 - val_loss: 0.5033 - val_accuracy: 0.8078
# Epoch 58/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4638 - accuracy: 0.8361 - val_loss: 0.5000 - val_accuracy: 0.8172
# Epoch 59/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4631 - accuracy: 0.8355 - val_loss: 0.4998 - val_accuracy: 0.8153
# Epoch 60/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4625 - accuracy: 0.8404 - val_loss: 0.5025 - val_accuracy: 0.8022
# Epoch 61/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4622 - accuracy: 0.8388 - val_loss: 0.4997 - val_accuracy: 0.8134
# Epoch 62/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4630 - accuracy: 0.8388 - val_loss: 0.5003 - val_accuracy: 0.8078
# Epoch 63/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4614 - accuracy: 0.8398 - val_loss: 0.4989 - val_accuracy: 0.8134
# Epoch 64/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4613 - accuracy: 0.8388 - val_loss: 0.4984 - val_accuracy: 0.8116
# Epoch 65/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4609 - accuracy: 0.8342 - val_loss: 0.4990 - val_accuracy: 0.8116
# Epoch 66/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4607 - accuracy: 0.8384 - val_loss: 0.4977 - val_accuracy: 0.8190
# Epoch 67/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4614 - accuracy: 0.8365 - val_loss: 0.5026 - val_accuracy: 0.7966
# Epoch 68/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4616 - accuracy: 0.8391 - val_loss: 0.4987 - val_accuracy: 0.8116
# Epoch 69/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4601 - accuracy: 0.8384 - val_loss: 0.4966 - val_accuracy: 0.8153
# Epoch 70/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4605 - accuracy: 0.8391 - val_loss: 0.4970 - val_accuracy: 0.8172
# Epoch 71/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4589 - accuracy: 0.8371 - val_loss: 0.4973 - val_accuracy: 0.8153
# Epoch 72/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4586 - accuracy: 0.8381 - val_loss: 0.4998 - val_accuracy: 0.7966
# Epoch 73/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4586 - accuracy: 0.8394 - val_loss: 0.4961 - val_accuracy: 0.8153
# Epoch 74/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4600 - accuracy: 0.8351 - val_loss: 0.4964 - val_accuracy: 0.8134
# Epoch 75/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4583 - accuracy: 0.8411 - val_loss: 0.4949 - val_accuracy: 0.8116
# Epoch 76/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4572 - accuracy: 0.8394 - val_loss: 0.4958 - val_accuracy: 0.8153
# Epoch 77/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4584 - accuracy: 0.8388 - val_loss: 0.4966 - val_accuracy: 0.8153
# Epoch 78/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4576 - accuracy: 0.8375 - val_loss: 0.4944 - val_accuracy: 0.8153
# Epoch 79/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4563 - accuracy: 0.8378 - val_loss: 0.4955 - val_accuracy: 0.8153
# Epoch 80/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4561 - accuracy: 0.8427 - val_loss: 0.4983 - val_accuracy: 0.7966
# Epoch 81/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4561 - accuracy: 0.8404 - val_loss: 0.4963 - val_accuracy: 0.8097
# Epoch 82/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4573 - accuracy: 0.8388 - val_loss: 0.4938 - val_accuracy: 0.8172
# Epoch 83/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4549 - accuracy: 0.8398 - val_loss: 0.4936 - val_accuracy: 0.8134
# Epoch 84/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4554 - accuracy: 0.8381 - val_loss: 0.4940 - val_accuracy: 0.8153
# Epoch 85/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4565 - accuracy: 0.8404 - val_loss: 0.4942 - val_accuracy: 0.8172
# Epoch 86/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4552 - accuracy: 0.8384 - val_loss: 0.4926 - val_accuracy: 0.8209
# Epoch 87/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4564 - accuracy: 0.8375 - val_loss: 0.4929 - val_accuracy: 0.8134
# Epoch 88/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4548 - accuracy: 0.8447 - val_loss: 0.4918 - val_accuracy: 0.8209
# Epoch 89/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4551 - accuracy: 0.8361 - val_loss: 0.4929 - val_accuracy: 0.8153
# Epoch 90/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4536 - accuracy: 0.8401 - val_loss: 0.4933 - val_accuracy: 0.8078
# Epoch 91/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4541 - accuracy: 0.8388 - val_loss: 0.4946 - val_accuracy: 0.8078
# Epoch 92/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4542 - accuracy: 0.8394 - val_loss: 0.4912 - val_accuracy: 0.8172
# Epoch 93/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4537 - accuracy: 0.8381 - val_loss: 0.4904 - val_accuracy: 0.8190
# Epoch 94/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4526 - accuracy: 0.8388 - val_loss: 0.4903 - val_accuracy: 0.8190
# Epoch 95/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4528 - accuracy: 0.8394 - val_loss: 0.4931 - val_accuracy: 0.8041
# Epoch 96/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4525 - accuracy: 0.8411 - val_loss: 0.4896 - val_accuracy: 0.8172
# Epoch 97/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4519 - accuracy: 0.8404 - val_loss: 0.4893 - val_accuracy: 0.8190
# Epoch 98/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4523 - accuracy: 0.8408 - val_loss: 0.4895 - val_accuracy: 0.8134
# Epoch 99/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4534 - accuracy: 0.8368 - val_loss: 0.4915 - val_accuracy: 0.8097
# Epoch 100/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4521 - accuracy: 0.8381 - val_loss: 0.4904 - val_accuracy: 0.8190
# Epoch 101/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4515 - accuracy: 0.8421 - val_loss: 0.4905 - val_accuracy: 0.8134
# Epoch 102/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4517 - accuracy: 0.8424 - val_loss: 0.4920 - val_accuracy: 0.8116

# %% [markdown]
# # evaluate model performance

# %% [markdown]
# #### scores

# %%
# Make predictions with the model
y_pred_prob = model.predict(X_test)  # Predicted probabilities
y_pred = np.where(y_pred_prob > 0.5, 1, 0)

# Calculate precision, recall, and F1 scores
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("")
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# 17/17 [==============================] - 0s 2ms/step
#
# Precision: 0.8318042813455657
# Recall: 0.8662420382165605
# F1-score: 0.8486739469578783
# 2023-07-08 18:05:02.151880: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# #### plot loss

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val-loss')
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
# Evaluate the model
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val-accuracy')
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %% [markdown]
# #### confusion matrix

# %%
cm = confusion_matrix(y_pred=y_pred, y_true=y_test)
cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])

cm_display.plot(cmap='Blues')
plt.show()

# %% [markdown]
# # save feature selection model

# %% [markdown]
# #### save model

# %%
# %%time
model_directory = get_config("model_directory")
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
full_model_path = os.path.join(model_directory, "nfl_features_model.keras")
model.save(full_model_path)
# Out:
# CPU times: user 16.3 ms, sys: 24.9 ms, total: 41.1 ms
# Wall time: 43.6 ms

# %% [markdown]
# #### save scaled and normalized data

# %%
# %%time
data_directory = get_config('data_directory')
if not os.path.exists(data_directory):
    os.makedirs(data_directory)

full_path = os.path.join(data_directory, "nfl_ml_features_scaled.npz")
np.savez(full_path, X=X, y=y)
# Out:
# CPU times: user 816 µs, sys: 1.35 ms, total: 2.16 ms
# Wall time: 1.55 ms

# %% [markdown]
# #### save features dataset

# %%
# %%time
full_path = os.path.join(data_directory, "nfl_ml_features.parquet")
stats_df.to_parquet(full_path)
# Out:
# CPU times: user 8.6 ms, sys: 5.27 ms, total: 13.9 ms
# Wall time: 18.4 ms
