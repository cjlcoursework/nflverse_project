# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import xgboost as xgb

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, f1_score


from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
import os
import sys

sys.path.append(os.path.abspath("../src"))

# %%
from src import *

# %%
db = database_loader.DatabaseLoader(get_config('connection_string'))
DEBUG = False
SCHEMA = 'controls'

file_name = "ml_stats_dataset"
data_directory = get_config('data_directory')

input_path = os.path.join(data_directory,  f"{file_name}.parquet")
assert  os.path.exists(input_path)

# %%
stats_df = pd.read_parquet(input_path)
stats_df.head()
# Out:
#        season  week  spread  rush_attempts  rush_touchdowns  pass_touchdowns  \
# index
# 0        2022     1     -23              0                1                2
# 1        2022     3      -8              3                0                0
# 2        2022     4      10              5                0                2
# 3        2022     6     -10              5                0                0
# 4        2022     7       8              2                1                1
#
#        interceptions  fumble  own_kickoff_recovery  safety  ...  \
# index                                                       ...
# 0                  0       6                     0       0  ...
# 1                  0       2                     0       0  ...
# 2                  1       3                     0       0  ...
# 3                  1       4                     0       0  ...
# 4                  0       2                     0       0  ...
#
#        passing_air_yards  passing_yards_after_catch  avg_dakota  carries  \
# index
# 0                  267.0                      115.0    0.007858     22.0
# 1                  356.0                      166.0   -0.000555     21.0
# 2                  180.0                       87.0    0.011065     37.0
# 3                  333.0                      114.0    0.003919     28.0
# 4                  216.0                       94.0    0.013561     29.0
#
#        rushing_yards  receptions  targets  receiving_yards  \
# index
# 0              103.0        24.0     36.0            205.0
# 1               70.0        37.0     55.0            314.0
# 2              132.0        23.0     31.0            207.0
# 3              144.0        23.0     36.0            222.0
# 4              137.0        20.0     29.0            204.0
#
#        receiving_air_yards  receiving_yards_after_catch
# index
# 0                    266.0                        115.0
# 1                    332.0                        166.0
# 2                    182.0                         87.0
# 3                    340.0                        114.0
# 4                    216.0                         94.0
#
# [5 rows x 63 columns]

# %%
stats_df['win'] = np.where(stats_df['spread'] > 0, 1, 0)
stats_df.drop(columns=['spread'], inplace=True)

# %%
dtype_mapping = {col: 'float' for col in stats_df.select_dtypes(include='int64')}
stats_df = stats_df.astype(dtype_mapping)

# %%
assert 0 == stats_df.isnull().sum().sum()

# %%
from typing import Set, Any


def correlate_to_target(df: pd.DataFrame, target_column: str, top_n: int) -> (pd.DataFrame, Set):

    # Calculate correlation matrix
    correlation_matrix = df.corr()

    # Filter and sort correlation coefficients by absolute value
    corr_df = pd.DataFrame(correlation_matrix.abs().unstack().sort_values(ascending=False))
    corr_df.reset_index(inplace=True)
    corr_df.columns = ['x', 'y', 'corr']

    not_self_correlated = (corr_df.y != target_column)
    win_correlated = (corr_df.x == target_column)

    df = corr_df.loc[ win_correlated & not_self_correlated ]\
        .sort_values(by='corr', ascending=False)\
        .drop(columns=['x'])\
        .head(top_n)\
        .copy()

    s = set(df['y'].values)

    return df, s


def calc_feature_importance(X: pd.DataFrame, y: pd.Series, top_n=30) -> (pd.DataFrame, Set):
    # Create an XGBoost model
    model = xgb.XGBRegressor()

    # Fit the model
    model.fit(X, y)

    # Get feature importance scores
    importance_scores = model.feature_importances_

    # Sort feature importance scores
    sorted_indices = importance_scores.argsort()[::-1]
    sorted_scores = importance_scores[sorted_indices]
    feature_names = X.columns[sorted_indices]

    # Get the top 'n' feature importance scores and names
    top_scores = sorted_scores[:top_n]
    top_features = feature_names[:top_n]
    df = pd.DataFrame({'y': top_features, 'corr': top_scores})

    set_xg_cols = set(top_features)
    return df, set(top_features)


def plot_correlations(scores: Any, features: Any, title: str):

    # Plot feature importance
    plt.figure(figsize=(10, 10))
    plt.barh(range(len(scores)), scores, align='center')
    plt.yticks(range(len(features)), features)
    plt.xlabel('Score')
    plt.ylabel('Column')
    plt.title(title)
    plt.show()

# %%
top_correlations, set_correlations = correlate_to_target(stats_df, 'win', 30)

# %%
import numpy as np


X = stats_df.drop(columns=['win']).copy()
y = stats_df['win']

print(X.shape)
print(y.shape)
y.value_counts()
# Out:
# (3569, 62)
# (3569,)
# 1.0    2064
# 0.0    1505
# Name: win, dtype: int64

# %%
top_features, set_features = calc_feature_importance(X, y, top_n=30)

# %%
plot_correlations(top_features['corr'], top_features['y'], "Feature Importance")
plot_correlations(top_correlations['corr'], top_correlations['y'], 'Feature Correlations')

# %%
target_columns = list(set_features.union(set_correlations))

# %%
X = X[target_columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Create the scaler object
scaler = MinMaxScaler()

# Normalize selected columns in a DataFrame
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
from keras.src.callbacks import EarlyStopping
from keras.src.optimizers import Adam
from keras import regularizers

learning_rate = .001

# Create a neural network model
model = Sequential()
model.add(Dense(32, input_dim=X.shape[1], activation='relu', kernel_regularizer=regularizers.l1(0.01)))
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l1(0.01)))
model.add(Dense(1, activation='sigmoid'))  # Single output neuron for binary classification

model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


# Train the model
r = model.fit(X_train, y_train, epochs=200, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 2023-07-08 17:42:27.144977: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2023-07-08 17:42:27.144999: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2023-07-08 17:42:27.145002: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2023-07-08 17:42:27.145181: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-08 17:42:27.145201: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
#  1/48 [..............................] - ETA: 16s - loss: 4.0231 - accuracy: 0.7031
# 2023-07-08 17:42:27.418549: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - 1s 12ms/step - loss: 3.5266 - accuracy: 0.6380 - val_loss: 3.0346 - val_accuracy: 0.6287
# Epoch 2/200
#  9/48 [====>.........................] - ETA: 0s - loss: 2.9533 - accuracy: 0.6649
# 2023-07-08 17:42:28.074298: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - 0s 8ms/step - loss: 2.6294 - accuracy: 0.6677 - val_loss: 2.2356 - val_accuracy: 0.6698
# Epoch 3/200
# 48/48 [==============================] - 0s 7ms/step - loss: 1.9118 - accuracy: 0.6805 - val_loss: 1.6072 - val_accuracy: 0.6716
# Epoch 4/200
# 48/48 [==============================] - 0s 8ms/step - loss: 1.3711 - accuracy: 0.6864 - val_loss: 1.1617 - val_accuracy: 0.7015
# Epoch 5/200
# 48/48 [==============================] - 0s 8ms/step - loss: 1.0036 - accuracy: 0.7349 - val_loss: 0.8739 - val_accuracy: 0.7090
# Epoch 6/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.7850 - accuracy: 0.7514 - val_loss: 0.7320 - val_accuracy: 0.7239
# Epoch 7/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6940 - accuracy: 0.7817 - val_loss: 0.6824 - val_accuracy: 0.7519
# Epoch 8/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.6509 - accuracy: 0.7962 - val_loss: 0.6539 - val_accuracy: 0.7649
# Epoch 9/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6221 - accuracy: 0.8061 - val_loss: 0.6375 - val_accuracy: 0.7612
# Epoch 10/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6001 - accuracy: 0.8098 - val_loss: 0.6166 - val_accuracy: 0.7724
# Epoch 11/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5859 - accuracy: 0.8111 - val_loss: 0.6088 - val_accuracy: 0.7780
# Epoch 12/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5765 - accuracy: 0.8114 - val_loss: 0.6002 - val_accuracy: 0.7724
# Epoch 13/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5678 - accuracy: 0.8210 - val_loss: 0.5937 - val_accuracy: 0.7761
# Epoch 14/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5613 - accuracy: 0.8197 - val_loss: 0.5888 - val_accuracy: 0.7817
# Epoch 15/200
# 48/48 [==============================] - 0s 9ms/step - loss: 0.5559 - accuracy: 0.8197 - val_loss: 0.5944 - val_accuracy: 0.7817
# Epoch 16/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5532 - accuracy: 0.8243 - val_loss: 0.5815 - val_accuracy: 0.7873
# Epoch 17/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5477 - accuracy: 0.8243 - val_loss: 0.5784 - val_accuracy: 0.7910
# Epoch 18/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5454 - accuracy: 0.8216 - val_loss: 0.5757 - val_accuracy: 0.7929
# Epoch 19/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5416 - accuracy: 0.8272 - val_loss: 0.5728 - val_accuracy: 0.7948
# Epoch 20/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5387 - accuracy: 0.8243 - val_loss: 0.5707 - val_accuracy: 0.7910
# Epoch 21/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5362 - accuracy: 0.8262 - val_loss: 0.5688 - val_accuracy: 0.7948
# Epoch 22/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5350 - accuracy: 0.8233 - val_loss: 0.5780 - val_accuracy: 0.7817
# Epoch 23/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5354 - accuracy: 0.8210 - val_loss: 0.5641 - val_accuracy: 0.7966
# Epoch 24/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5294 - accuracy: 0.8259 - val_loss: 0.5641 - val_accuracy: 0.7948
# Epoch 25/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5285 - accuracy: 0.8282 - val_loss: 0.5604 - val_accuracy: 0.7948
# Epoch 26/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5272 - accuracy: 0.8233 - val_loss: 0.5595 - val_accuracy: 0.7929
# Epoch 27/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5242 - accuracy: 0.8246 - val_loss: 0.5572 - val_accuracy: 0.7948
# Epoch 28/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5232 - accuracy: 0.8286 - val_loss: 0.5559 - val_accuracy: 0.7929
# Epoch 29/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5212 - accuracy: 0.8272 - val_loss: 0.5540 - val_accuracy: 0.7948
# Epoch 30/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5195 - accuracy: 0.8299 - val_loss: 0.5535 - val_accuracy: 0.7929
# Epoch 31/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5189 - accuracy: 0.8239 - val_loss: 0.5521 - val_accuracy: 0.7929
# Epoch 32/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5171 - accuracy: 0.8279 - val_loss: 0.5499 - val_accuracy: 0.7985
# Epoch 33/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5165 - accuracy: 0.8309 - val_loss: 0.5527 - val_accuracy: 0.7948
# Epoch 34/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5155 - accuracy: 0.8312 - val_loss: 0.5474 - val_accuracy: 0.7966
# Epoch 35/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5132 - accuracy: 0.8302 - val_loss: 0.5463 - val_accuracy: 0.8004
# Epoch 36/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5136 - accuracy: 0.8246 - val_loss: 0.5451 - val_accuracy: 0.8022
# Epoch 37/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5102 - accuracy: 0.8318 - val_loss: 0.5444 - val_accuracy: 0.7948
# Epoch 38/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5102 - accuracy: 0.8318 - val_loss: 0.5424 - val_accuracy: 0.8022
# Epoch 39/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5088 - accuracy: 0.8322 - val_loss: 0.5414 - val_accuracy: 0.8041
# Epoch 40/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5083 - accuracy: 0.8295 - val_loss: 0.5410 - val_accuracy: 0.7985
# Epoch 41/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5068 - accuracy: 0.8309 - val_loss: 0.5399 - val_accuracy: 0.8004
# Epoch 42/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5059 - accuracy: 0.8312 - val_loss: 0.5388 - val_accuracy: 0.8022
# Epoch 43/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5051 - accuracy: 0.8322 - val_loss: 0.5381 - val_accuracy: 0.8060
# Epoch 44/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5045 - accuracy: 0.8289 - val_loss: 0.5381 - val_accuracy: 0.7948
# Epoch 45/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5029 - accuracy: 0.8328 - val_loss: 0.5368 - val_accuracy: 0.7948
# Epoch 46/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.5033 - accuracy: 0.8322 - val_loss: 0.5375 - val_accuracy: 0.8004
# Epoch 47/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5010 - accuracy: 0.8279 - val_loss: 0.5386 - val_accuracy: 0.7948
# Epoch 48/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4999 - accuracy: 0.8348 - val_loss: 0.5340 - val_accuracy: 0.8022
# Epoch 49/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4990 - accuracy: 0.8345 - val_loss: 0.5322 - val_accuracy: 0.8041
# Epoch 50/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4985 - accuracy: 0.8322 - val_loss: 0.5331 - val_accuracy: 0.8004
# Epoch 51/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4982 - accuracy: 0.8345 - val_loss: 0.5318 - val_accuracy: 0.8022
# Epoch 52/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4967 - accuracy: 0.8312 - val_loss: 0.5311 - val_accuracy: 0.8004
# Epoch 53/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4961 - accuracy: 0.8355 - val_loss: 0.5296 - val_accuracy: 0.8041
# Epoch 54/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4951 - accuracy: 0.8332 - val_loss: 0.5286 - val_accuracy: 0.8041
# Epoch 55/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4947 - accuracy: 0.8309 - val_loss: 0.5279 - val_accuracy: 0.8060
# Epoch 56/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4934 - accuracy: 0.8345 - val_loss: 0.5370 - val_accuracy: 0.7892
# Epoch 57/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4958 - accuracy: 0.8322 - val_loss: 0.5275 - val_accuracy: 0.8078
# Epoch 58/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4938 - accuracy: 0.8345 - val_loss: 0.5272 - val_accuracy: 0.8060
# Epoch 59/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4922 - accuracy: 0.8365 - val_loss: 0.5252 - val_accuracy: 0.8116
# Epoch 60/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4912 - accuracy: 0.8361 - val_loss: 0.5243 - val_accuracy: 0.8060
# Epoch 61/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4899 - accuracy: 0.8318 - val_loss: 0.5233 - val_accuracy: 0.8097
# Epoch 62/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4891 - accuracy: 0.8355 - val_loss: 0.5231 - val_accuracy: 0.8060
# Epoch 63/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4877 - accuracy: 0.8351 - val_loss: 0.5248 - val_accuracy: 0.8004
# Epoch 64/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4890 - accuracy: 0.8328 - val_loss: 0.5208 - val_accuracy: 0.8078
# Epoch 65/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4866 - accuracy: 0.8325 - val_loss: 0.5206 - val_accuracy: 0.8097
# Epoch 66/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4867 - accuracy: 0.8325 - val_loss: 0.5201 - val_accuracy: 0.8078
# Epoch 67/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4853 - accuracy: 0.8355 - val_loss: 0.5191 - val_accuracy: 0.8097
# Epoch 68/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4847 - accuracy: 0.8384 - val_loss: 0.5182 - val_accuracy: 0.8060
# Epoch 69/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4835 - accuracy: 0.8378 - val_loss: 0.5174 - val_accuracy: 0.8097
# Epoch 70/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4836 - accuracy: 0.8358 - val_loss: 0.5174 - val_accuracy: 0.8116
# Epoch 71/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4816 - accuracy: 0.8351 - val_loss: 0.5157 - val_accuracy: 0.8097
# Epoch 72/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4799 - accuracy: 0.8381 - val_loss: 0.5216 - val_accuracy: 0.7929
# Epoch 73/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4800 - accuracy: 0.8381 - val_loss: 0.5167 - val_accuracy: 0.8004
# Epoch 74/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4818 - accuracy: 0.8345 - val_loss: 0.5145 - val_accuracy: 0.8060
# Epoch 75/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4804 - accuracy: 0.8375 - val_loss: 0.5143 - val_accuracy: 0.8153
# Epoch 76/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4790 - accuracy: 0.8371 - val_loss: 0.5131 - val_accuracy: 0.8116
# Epoch 77/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4779 - accuracy: 0.8384 - val_loss: 0.5115 - val_accuracy: 0.8041
# Epoch 78/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4767 - accuracy: 0.8378 - val_loss: 0.5118 - val_accuracy: 0.8060
# Epoch 79/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4768 - accuracy: 0.8348 - val_loss: 0.5104 - val_accuracy: 0.8116
# Epoch 80/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4757 - accuracy: 0.8345 - val_loss: 0.5105 - val_accuracy: 0.8078
# Epoch 81/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4735 - accuracy: 0.8338 - val_loss: 0.5081 - val_accuracy: 0.8116
# Epoch 82/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4734 - accuracy: 0.8388 - val_loss: 0.5082 - val_accuracy: 0.8097
# Epoch 83/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4715 - accuracy: 0.8388 - val_loss: 0.5073 - val_accuracy: 0.8078
# Epoch 84/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4713 - accuracy: 0.8384 - val_loss: 0.5083 - val_accuracy: 0.8004
# Epoch 85/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4706 - accuracy: 0.8361 - val_loss: 0.5053 - val_accuracy: 0.8116
# Epoch 86/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4730 - accuracy: 0.8345 - val_loss: 0.5119 - val_accuracy: 0.7910
# Epoch 87/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4702 - accuracy: 0.8371 - val_loss: 0.5059 - val_accuracy: 0.8022
# Epoch 88/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4686 - accuracy: 0.8348 - val_loss: 0.5034 - val_accuracy: 0.8097
# Epoch 89/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4695 - accuracy: 0.8358 - val_loss: 0.5062 - val_accuracy: 0.8041
# Epoch 90/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4681 - accuracy: 0.8355 - val_loss: 0.5033 - val_accuracy: 0.8078
# Epoch 91/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4659 - accuracy: 0.8391 - val_loss: 0.5013 - val_accuracy: 0.8097
# Epoch 92/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4655 - accuracy: 0.8394 - val_loss: 0.5028 - val_accuracy: 0.8022
# Epoch 93/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4664 - accuracy: 0.8398 - val_loss: 0.5010 - val_accuracy: 0.8097
# Epoch 94/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4659 - accuracy: 0.8384 - val_loss: 0.5068 - val_accuracy: 0.7929
# Epoch 95/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4652 - accuracy: 0.8351 - val_loss: 0.5004 - val_accuracy: 0.8097
# Epoch 96/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4650 - accuracy: 0.8375 - val_loss: 0.5013 - val_accuracy: 0.8097
# Epoch 97/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4639 - accuracy: 0.8368 - val_loss: 0.4979 - val_accuracy: 0.8116
# Epoch 98/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4614 - accuracy: 0.8404 - val_loss: 0.5023 - val_accuracy: 0.8004
# Epoch 99/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4627 - accuracy: 0.8355 - val_loss: 0.4970 - val_accuracy: 0.8116
# Epoch 100/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4607 - accuracy: 0.8358 - val_loss: 0.4966 - val_accuracy: 0.8134
# Epoch 101/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4607 - accuracy: 0.8391 - val_loss: 0.4962 - val_accuracy: 0.8097
# Epoch 102/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4588 - accuracy: 0.8391 - val_loss: 0.4946 - val_accuracy: 0.8116
# Epoch 103/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4589 - accuracy: 0.8361 - val_loss: 0.4945 - val_accuracy: 0.8116
# Epoch 104/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4587 - accuracy: 0.8384 - val_loss: 0.4938 - val_accuracy: 0.8153
# Epoch 105/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4581 - accuracy: 0.8351 - val_loss: 0.4941 - val_accuracy: 0.8116
# Epoch 106/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4555 - accuracy: 0.8391 - val_loss: 0.4929 - val_accuracy: 0.8078
# Epoch 107/200
# 48/48 [==============================] - 0s 8ms/step - loss: 0.4571 - accuracy: 0.8437 - val_loss: 0.4944 - val_accuracy: 0.8097
# Epoch 108/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4569 - accuracy: 0.8391 - val_loss: 0.4921 - val_accuracy: 0.8078
# Epoch 109/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4535 - accuracy: 0.8440 - val_loss: 0.4910 - val_accuracy: 0.8078
# Epoch 110/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4539 - accuracy: 0.8414 - val_loss: 0.4898 - val_accuracy: 0.8116
# Epoch 111/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4538 - accuracy: 0.8388 - val_loss: 0.4898 - val_accuracy: 0.8116
# Epoch 112/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4528 - accuracy: 0.8411 - val_loss: 0.4891 - val_accuracy: 0.8134
# Epoch 113/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4523 - accuracy: 0.8398 - val_loss: 0.4911 - val_accuracy: 0.8022
# Epoch 114/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4530 - accuracy: 0.8408 - val_loss: 0.4882 - val_accuracy: 0.8134
# Epoch 115/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4501 - accuracy: 0.8421 - val_loss: 0.4898 - val_accuracy: 0.8041
# Epoch 116/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4501 - accuracy: 0.8391 - val_loss: 0.4873 - val_accuracy: 0.8116
# Epoch 117/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4522 - accuracy: 0.8414 - val_loss: 0.4899 - val_accuracy: 0.8116
# Epoch 118/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4508 - accuracy: 0.8398 - val_loss: 0.4870 - val_accuracy: 0.8153
# Epoch 119/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4489 - accuracy: 0.8424 - val_loss: 0.4857 - val_accuracy: 0.8134
# Epoch 120/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4482 - accuracy: 0.8424 - val_loss: 0.4850 - val_accuracy: 0.8134
# Epoch 121/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4482 - accuracy: 0.8381 - val_loss: 0.4858 - val_accuracy: 0.8134
# Epoch 122/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4472 - accuracy: 0.8375 - val_loss: 0.4873 - val_accuracy: 0.7966
# Epoch 123/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4487 - accuracy: 0.8437 - val_loss: 0.4842 - val_accuracy: 0.8134
# Epoch 124/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4470 - accuracy: 0.8404 - val_loss: 0.4834 - val_accuracy: 0.8209
# Epoch 125/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4459 - accuracy: 0.8391 - val_loss: 0.4842 - val_accuracy: 0.8153
# Epoch 126/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4453 - accuracy: 0.8398 - val_loss: 0.4833 - val_accuracy: 0.8134
# Epoch 127/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4456 - accuracy: 0.8417 - val_loss: 0.4851 - val_accuracy: 0.8060
# Epoch 128/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4448 - accuracy: 0.8394 - val_loss: 0.4896 - val_accuracy: 0.7948
# Epoch 129/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4475 - accuracy: 0.8414 - val_loss: 0.4849 - val_accuracy: 0.8153
# Epoch 130/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4452 - accuracy: 0.8398 - val_loss: 0.4846 - val_accuracy: 0.8004
# Epoch 131/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4451 - accuracy: 0.8417 - val_loss: 0.4818 - val_accuracy: 0.8172
# Epoch 132/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4445 - accuracy: 0.8391 - val_loss: 0.4817 - val_accuracy: 0.8190
# Epoch 133/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4437 - accuracy: 0.8408 - val_loss: 0.4854 - val_accuracy: 0.8078
# Epoch 134/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4471 - accuracy: 0.8388 - val_loss: 0.4909 - val_accuracy: 0.7948
# Epoch 135/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4465 - accuracy: 0.8365 - val_loss: 0.4811 - val_accuracy: 0.8153
# Epoch 136/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4430 - accuracy: 0.8401 - val_loss: 0.4809 - val_accuracy: 0.8153
# Epoch 137/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4439 - accuracy: 0.8408 - val_loss: 0.4809 - val_accuracy: 0.8172
# Epoch 138/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4446 - accuracy: 0.8408 - val_loss: 0.4820 - val_accuracy: 0.8190
# Epoch 139/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4436 - accuracy: 0.8384 - val_loss: 0.4806 - val_accuracy: 0.8116
# Epoch 140/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4432 - accuracy: 0.8404 - val_loss: 0.4841 - val_accuracy: 0.7985
# Epoch 141/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4434 - accuracy: 0.8408 - val_loss: 0.4818 - val_accuracy: 0.8116
# Epoch 142/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4424 - accuracy: 0.8391 - val_loss: 0.4834 - val_accuracy: 0.8041
# Epoch 143/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4427 - accuracy: 0.8408 - val_loss: 0.4807 - val_accuracy: 0.8116
# Epoch 144/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4422 - accuracy: 0.8417 - val_loss: 0.4848 - val_accuracy: 0.7948

# %%
# Make predictions with the model
y_pred_prob = model.predict(X_test)  # Predicted probabilities
y_pred = np.where(y_pred_prob > 0.5, 1, 0)

# Calculate precision, recall, and F1 scores
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("")
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# 17/17 [==============================] - 0s 2ms/step
#
# Precision: 0.8160237388724035
# Recall: 0.8757961783439491
# F1-score: 0.8448540706605222
# 2023-07-08 17:43:18.834222: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val-loss')
plt.legend()
plt.show()

# %%
# Evaluate the model
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val-accuracy')
plt.legend()
plt.show()

# %%
cm = confusion_matrix(y_pred=y_pred, y_true=y_test)
cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])

cm_display.plot(cmap='Blues')
plt.show()

# %%
model_directory = get_config("model_directory")
if not os.path.exists(model_directory):
    os.makedirs(model_directory)
full_model_path = os.path.join(model_directory, "nfl_features_model.keras")
model.save(full_model_path)

# %%
data_directory = get_config('data_directory')
if not os.path.exists(data_directory):
    os.makedirs(data_directory)

full_path = os.path.join(data_directory, "nfl_ml_features_scaled.npz")
np.savez(full_path, X=X, y=y)

# %%
full_path = os.path.join(data_directory, "nfl_ml_features.parquet")
stats_df.to_parquet(full_path)
