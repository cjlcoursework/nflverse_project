# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import xgboost as xgb

from typing import Set

from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
import os
import sys

sys.path.append(os.path.abspath("../src"))

# %%
from src import *

# %%
db = database_loader.DatabaseLoader(get_config('connection_string'))
DEBUG = False
SCHEMA = 'controls'

file_name = "ml_stats_dataset"
data_directory = get_config('data_directory')
project_name = get_config('project_name')

input_path = os.path.join(data_directory, project_name,  f"{file_name}.parquet")
assert  os.path.exists(input_path)

# %%
stats_df = pd.read_parquet(input_path)
stats_df.head()
# Out:
#        season  week  spread  rush_attempts  rush_touchdowns  pass_touchdowns  \
# index
# 0        2022     1     -23              0                1                2
# 1        2022     3      -8              3                0                0
# 2        2022     4      10              5                0                2
# 3        2022     6     -10              5                0                0
# 4        2022     7       8              2                1                1
#
#        interceptions  fumble  own_kickoff_recovery  safety  ...  \
# index                                                       ...
# 0                  0       6                     0       0  ...
# 1                  0       2                     0       0  ...
# 2                  1       3                     0       0  ...
# 3                  1       4                     0       0  ...
# 4                  0       2                     0       0  ...
#
#        passing_air_yards  passing_yards_after_catch  avg_dakota  carries  \
# index
# 0                  267.0                      115.0    0.007858     22.0
# 1                  356.0                      166.0   -0.000555     21.0
# 2                  180.0                       87.0    0.011065     37.0
# 3                  333.0                      114.0    0.003919     28.0
# 4                  216.0                       94.0    0.013561     29.0
#
#        rushing_yards  receptions  targets  receiving_yards  \
# index
# 0              103.0        24.0     36.0            205.0
# 1               70.0        37.0     55.0            314.0
# 2              132.0        23.0     31.0            207.0
# 3              144.0        23.0     36.0            222.0
# 4              137.0        20.0     29.0            204.0
#
#        receiving_air_yards  receiving_yards_after_catch
# index
# 0                    266.0                        115.0
# 1                    332.0                        166.0
# 2                    182.0                         87.0
# 3                    340.0                        114.0
# 4                    216.0                         94.0
#
# [5 rows x 63 columns]

# %%
stats_df['win'] = np.where(stats_df['spread'] > 0, 1, 0)
stats_df.drop(columns=['spread'], inplace=True)

# %%
dtype_mapping = {col: 'float' for col in stats_df.select_dtypes(include='int64')}
stats_df = stats_df.astype(dtype_mapping)

# %%
assert 0 == stats_df.isnull().sum().sum()

# %%
from typing import Set, Any


def correlate_to_target(df: pd.DataFrame, target_column: str, top_n: int) -> (pd.DataFrame, Set):

    # Calculate correlation matrix
    correlation_matrix = df.corr()

    # Filter and sort correlation coefficients by absolute value
    corr_df = pd.DataFrame(correlation_matrix.abs().unstack().sort_values(ascending=False))
    corr_df.reset_index(inplace=True)
    corr_df.columns = ['x', 'y', 'corr']

    not_self_correlated = (corr_df.y != target_column)
    win_correlated = (corr_df.x == target_column)

    df = corr_df.loc[ win_correlated & not_self_correlated ]\
        .sort_values(by='corr', ascending=False)\
        .drop(columns=['x'])\
        .head(top_n)\
        .copy()

    s = set(df['y'].values)

    return df, s


def calc_feature_importance(X: pd.DataFrame, y: pd.Series, top_n=30) -> (pd.DataFrame, Set):
    # Create an XGBoost model
    model = xgb.XGBRegressor()

    # Fit the model
    model.fit(X, y)

    # Get feature importance scores
    importance_scores = model.feature_importances_

    # Sort feature importance scores
    sorted_indices = importance_scores.argsort()[::-1]
    sorted_scores = importance_scores[sorted_indices]
    feature_names = X.columns[sorted_indices]

    # Get the top 'n' feature importance scores and names
    top_scores = sorted_scores[:top_n]
    top_features = feature_names[:top_n]
    df = pd.DataFrame({'y': top_features, 'corr': top_scores})

    set_xg_cols = set(top_features)
    return df, set(top_features)


def plot_correlations(scores: Any, features: Any, title: str):

    # Plot feature importance
    plt.figure(figsize=(10, 10))
    plt.barh(range(len(scores)), scores, align='center')
    plt.yticks(range(len(features)), features)
    plt.xlabel('Score')
    plt.ylabel('Column')
    plt.title(title)
    plt.show()

# %%
top_correlations, set_correlations = correlate_to_target(stats_df, 'win', 30)

# %%
import numpy as np


X = stats_df.drop(columns=['win']).copy()
y = stats_df['win']

print(X.shape)
print(y.shape)
y.value_counts()
# Out:
# (3569, 62)
# (3569,)
# 1.0    2064
# 0.0    1505
# Name: win, dtype: int64

# %%
top_features, set_features = calc_feature_importance(X, y, top_n=30)

# %%
plot_correlations(top_features['corr'], top_features['y'], "Feature Importance")
plot_correlations(top_correlations['corr'], top_correlations['y'], 'Feature Correlations')

# %%
target_columns = list(set_features.union(set_correlations))

# %%
X = X[target_columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Create the scaler object
scaler = MinMaxScaler()

# Normalize selected columns in a DataFrame
X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
from keras.src.callbacks import EarlyStopping
from keras.src.optimizers import Adam
from keras import regularizers

learning_rate = .001

# Create a neural network model
model = Sequential()
model.add(Dense(32, input_dim=X.shape[1], activation='relu', kernel_regularizer=regularizers.l1(0.01)))
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l1(0.01)))
model.add(Dense(1, activation='sigmoid'))  # Single output neuron for binary classification

model.compile(
    optimizer=Adam(learning_rate=learning_rate),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


# Train the model
r = model.fit(X_train, y_train, epochs=200, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 2023-07-08 13:10:07.657521: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2023-07-08 13:10:07.657539: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2023-07-08 13:10:07.657542: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2023-07-08 13:10:07.657567: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-08 13:10:07.657580: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
#  1/48 [..............................] - ETA: 14s - loss: 4.0640 - accuracy: 0.5781
# 2023-07-08 13:10:07.918939: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - 1s 11ms/step - loss: 3.5832 - accuracy: 0.5925 - val_loss: 3.0929 - val_accuracy: 0.5840
# Epoch 2/200
# 10/48 [=====>........................] - ETA: 0s - loss: 3.0096 - accuracy: 0.5922
# 2023-07-08 13:10:08.485252: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 48/48 [==============================] - 0s 7ms/step - loss: 2.6897 - accuracy: 0.5889 - val_loss: 2.2828 - val_accuracy: 0.5933
# Epoch 3/200
# 48/48 [==============================] - 0s 7ms/step - loss: 1.9572 - accuracy: 0.5895 - val_loss: 1.6374 - val_accuracy: 0.5914
# Epoch 4/200
# 48/48 [==============================] - 0s 7ms/step - loss: 1.3946 - accuracy: 0.5839 - val_loss: 1.1655 - val_accuracy: 0.5858
# Epoch 5/200
# 48/48 [==============================] - 0s 7ms/step - loss: 1.0068 - accuracy: 0.5800 - val_loss: 0.8692 - val_accuracy: 0.5858
# Epoch 6/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.7888 - accuracy: 0.5836 - val_loss: 0.7274 - val_accuracy: 0.5858
# Epoch 7/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6961 - accuracy: 0.6192 - val_loss: 0.6774 - val_accuracy: 0.6343
# Epoch 8/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6553 - accuracy: 0.7003 - val_loss: 0.6478 - val_accuracy: 0.7052
# Epoch 9/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.6234 - accuracy: 0.7511 - val_loss: 0.6205 - val_accuracy: 0.7575
# Epoch 10/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5935 - accuracy: 0.7933 - val_loss: 0.5978 - val_accuracy: 0.7593
# Epoch 11/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5684 - accuracy: 0.8055 - val_loss: 0.5791 - val_accuracy: 0.7668
# Epoch 12/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5485 - accuracy: 0.8114 - val_loss: 0.5677 - val_accuracy: 0.7668
# Epoch 13/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5354 - accuracy: 0.8124 - val_loss: 0.5561 - val_accuracy: 0.7705
# Epoch 14/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5260 - accuracy: 0.8134 - val_loss: 0.5499 - val_accuracy: 0.7724
# Epoch 15/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5190 - accuracy: 0.8206 - val_loss: 0.5435 - val_accuracy: 0.7780
# Epoch 16/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5129 - accuracy: 0.8144 - val_loss: 0.5388 - val_accuracy: 0.7780
# Epoch 17/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5075 - accuracy: 0.8216 - val_loss: 0.5353 - val_accuracy: 0.7948
# Epoch 18/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5036 - accuracy: 0.8253 - val_loss: 0.5320 - val_accuracy: 0.7836
# Epoch 19/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5015 - accuracy: 0.8253 - val_loss: 0.5297 - val_accuracy: 0.7910
# Epoch 20/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.5000 - accuracy: 0.8226 - val_loss: 0.5272 - val_accuracy: 0.7873
# Epoch 21/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4948 - accuracy: 0.8276 - val_loss: 0.5251 - val_accuracy: 0.7910
# Epoch 22/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4923 - accuracy: 0.8276 - val_loss: 0.5241 - val_accuracy: 0.7873
# Epoch 23/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4903 - accuracy: 0.8266 - val_loss: 0.5224 - val_accuracy: 0.7910
# Epoch 24/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4903 - accuracy: 0.8286 - val_loss: 0.5226 - val_accuracy: 0.7892
# Epoch 25/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4873 - accuracy: 0.8289 - val_loss: 0.5184 - val_accuracy: 0.7910
# Epoch 26/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4857 - accuracy: 0.8305 - val_loss: 0.5171 - val_accuracy: 0.7910
# Epoch 27/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4848 - accuracy: 0.8332 - val_loss: 0.5161 - val_accuracy: 0.7985
# Epoch 28/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4834 - accuracy: 0.8322 - val_loss: 0.5148 - val_accuracy: 0.8004
# Epoch 29/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4815 - accuracy: 0.8272 - val_loss: 0.5135 - val_accuracy: 0.8004
# Epoch 30/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4799 - accuracy: 0.8318 - val_loss: 0.5123 - val_accuracy: 0.8004
# Epoch 31/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4791 - accuracy: 0.8318 - val_loss: 0.5132 - val_accuracy: 0.7966
# Epoch 32/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4784 - accuracy: 0.8335 - val_loss: 0.5110 - val_accuracy: 0.8004
# Epoch 33/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4770 - accuracy: 0.8345 - val_loss: 0.5106 - val_accuracy: 0.8097
# Epoch 34/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4762 - accuracy: 0.8309 - val_loss: 0.5097 - val_accuracy: 0.8004
# Epoch 35/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4751 - accuracy: 0.8332 - val_loss: 0.5134 - val_accuracy: 0.8022
# Epoch 36/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4757 - accuracy: 0.8328 - val_loss: 0.5108 - val_accuracy: 0.7985
# Epoch 37/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4743 - accuracy: 0.8305 - val_loss: 0.5082 - val_accuracy: 0.7929
# Epoch 38/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4730 - accuracy: 0.8338 - val_loss: 0.5093 - val_accuracy: 0.7985
# Epoch 39/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4727 - accuracy: 0.8345 - val_loss: 0.5063 - val_accuracy: 0.8060
# Epoch 40/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4710 - accuracy: 0.8365 - val_loss: 0.5062 - val_accuracy: 0.8097
# Epoch 41/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4707 - accuracy: 0.8335 - val_loss: 0.5053 - val_accuracy: 0.8116
# Epoch 42/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4693 - accuracy: 0.8368 - val_loss: 0.5083 - val_accuracy: 0.8004
# Epoch 43/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4720 - accuracy: 0.8355 - val_loss: 0.5052 - val_accuracy: 0.8134
# Epoch 44/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4701 - accuracy: 0.8345 - val_loss: 0.5043 - val_accuracy: 0.8097
# Epoch 45/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4680 - accuracy: 0.8335 - val_loss: 0.5043 - val_accuracy: 0.8078
# Epoch 46/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4691 - accuracy: 0.8375 - val_loss: 0.5030 - val_accuracy: 0.8153
# Epoch 47/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4675 - accuracy: 0.8381 - val_loss: 0.5030 - val_accuracy: 0.8116
# Epoch 48/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4673 - accuracy: 0.8361 - val_loss: 0.5096 - val_accuracy: 0.7910
# Epoch 49/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4676 - accuracy: 0.8365 - val_loss: 0.5067 - val_accuracy: 0.7966
# Epoch 50/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4671 - accuracy: 0.8361 - val_loss: 0.5014 - val_accuracy: 0.8134
# Epoch 51/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4658 - accuracy: 0.8378 - val_loss: 0.5010 - val_accuracy: 0.8153
# Epoch 52/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4680 - accuracy: 0.8368 - val_loss: 0.5048 - val_accuracy: 0.8004
# Epoch 53/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4656 - accuracy: 0.8371 - val_loss: 0.5003 - val_accuracy: 0.8153
# Epoch 54/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4644 - accuracy: 0.8378 - val_loss: 0.5000 - val_accuracy: 0.8153
# Epoch 55/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4636 - accuracy: 0.8375 - val_loss: 0.4999 - val_accuracy: 0.8097
# Epoch 56/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4647 - accuracy: 0.8388 - val_loss: 0.4997 - val_accuracy: 0.8172
# Epoch 57/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4672 - accuracy: 0.8384 - val_loss: 0.5011 - val_accuracy: 0.8134
# Epoch 58/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4637 - accuracy: 0.8394 - val_loss: 0.4994 - val_accuracy: 0.8116
# Epoch 59/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4638 - accuracy: 0.8404 - val_loss: 0.4985 - val_accuracy: 0.8134
# Epoch 60/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4625 - accuracy: 0.8398 - val_loss: 0.4980 - val_accuracy: 0.8172
# Epoch 61/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4614 - accuracy: 0.8361 - val_loss: 0.4998 - val_accuracy: 0.8097
# Epoch 62/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4633 - accuracy: 0.8414 - val_loss: 0.4997 - val_accuracy: 0.8022
# Epoch 63/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4610 - accuracy: 0.8378 - val_loss: 0.4968 - val_accuracy: 0.8172
# Epoch 64/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4616 - accuracy: 0.8365 - val_loss: 0.4983 - val_accuracy: 0.8097
# Epoch 65/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4609 - accuracy: 0.8378 - val_loss: 0.4984 - val_accuracy: 0.8060
# Epoch 66/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4623 - accuracy: 0.8378 - val_loss: 0.4982 - val_accuracy: 0.8078
# Epoch 67/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4599 - accuracy: 0.8391 - val_loss: 0.4962 - val_accuracy: 0.8153
# Epoch 68/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4588 - accuracy: 0.8401 - val_loss: 0.4955 - val_accuracy: 0.8172
# Epoch 69/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4586 - accuracy: 0.8388 - val_loss: 0.4949 - val_accuracy: 0.8172
# Epoch 70/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4581 - accuracy: 0.8398 - val_loss: 0.4946 - val_accuracy: 0.8153
# Epoch 71/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4586 - accuracy: 0.8391 - val_loss: 0.4947 - val_accuracy: 0.8172
# Epoch 72/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4582 - accuracy: 0.8404 - val_loss: 0.4959 - val_accuracy: 0.8134
# Epoch 73/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4592 - accuracy: 0.8391 - val_loss: 0.4950 - val_accuracy: 0.8134
# Epoch 74/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4582 - accuracy: 0.8431 - val_loss: 0.4950 - val_accuracy: 0.8116
# Epoch 75/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4576 - accuracy: 0.8365 - val_loss: 0.4938 - val_accuracy: 0.8153
# Epoch 76/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4586 - accuracy: 0.8398 - val_loss: 0.4946 - val_accuracy: 0.8172
# Epoch 77/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4569 - accuracy: 0.8414 - val_loss: 0.4934 - val_accuracy: 0.8172
# Epoch 78/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4571 - accuracy: 0.8414 - val_loss: 0.4929 - val_accuracy: 0.8172
# Epoch 79/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4567 - accuracy: 0.8381 - val_loss: 0.4926 - val_accuracy: 0.8190
# Epoch 80/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4566 - accuracy: 0.8391 - val_loss: 0.4944 - val_accuracy: 0.8153
# Epoch 81/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4558 - accuracy: 0.8401 - val_loss: 0.4951 - val_accuracy: 0.8078
# Epoch 82/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4552 - accuracy: 0.8411 - val_loss: 0.4962 - val_accuracy: 0.8004
# Epoch 83/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4571 - accuracy: 0.8378 - val_loss: 0.4927 - val_accuracy: 0.8190
# Epoch 84/200
# 48/48 [==============================] - 0s 7ms/step - loss: 0.4551 - accuracy: 0.8401 - val_loss: 0.4952 - val_accuracy: 0.8060

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val-loss')
plt.legend()
plt.show()

# %%
# Evaluate the model
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val-accuracy')
plt.legend()
plt.show()
